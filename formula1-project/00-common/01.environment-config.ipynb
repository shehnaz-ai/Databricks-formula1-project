// %% [markdown]
// ### Databricks notebook source
// ### Unity Catalog Object Names

// %%
val catalog_name = "formula1"
val bronze_schema = "bronze"
val silver_schema = "silver"
val gold_schema = "gold"
val landing_folder_path = "/Volumes/formula1/landing/files"
